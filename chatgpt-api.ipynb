# %%
# !pip install OpenAI

# %%
code = ''
with open('/kaggle/input/coding/code.txt','r') as f:
    code = ''.join(f.readlines())

# %%
problem_link = 'https://www.acmicpc.net/problem/32288'
content = f'problem : {problem_link}, code : {code}, I am a student preparing for a job and would like to improve my coding test skills required by companies. Could you review simply this code and suggest areas for improvement? Also, could you recommend one additional problem that would help enhance my skills and in https://www.acmicpc.net?'

# %%
from openai import OpenAI 

client = OpenAI(api_key = key)
response = client.chat.completions.create(model='gpt-4o',
                                          messages = [{'role':'user', 
                                                    'content':content}],
                                         temperature = 0.1)
print(response.choices[0].message.content)
# Out:
# Certainly! Let's review your code first:
#
# ### Code Review
#
# 1. **Functionality**: Your code correctly toggles the case of each letter in the input string `s`. It uses a list comprehension to iterate over each character and checks if it is a lowercase letter. If it is, it converts it to uppercase; otherwise, it converts it to lowercase.
#
# 2. **Efficiency**: The code is efficient for the task at hand. The use of list comprehension is both concise and fast for this kind of operation.
#
# 3. **Readability**: The code is quite readable, but you can improve it slightly by adding comments or breaking it into functions for clarity, especially in more complex scenarios.
#
# 4. **Edge Cases**: Consider what happens if the input string is empty or contains non-alphabetic characters. Your code handles these cases correctly, but it's always good to think about them.
#
# ...
